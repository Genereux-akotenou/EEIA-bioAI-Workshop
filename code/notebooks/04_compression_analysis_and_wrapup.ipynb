# %% [markdown]
# # Day 4 — Compression analysis & wrap-up
#
# Bring together every model built this week: accuracy, parameter count, and inference
# latency, on one chart. This is the payoff of the whole pipeline — how much of the Evo2
# teacher's accuracy can a compressed model keep, at what fraction of the cost?
#
# Fill in the `results` dict below with the numbers you collected in notebooks 01–03
# (the exact values will differ run to run — re-run the relevant cells if needed).

# %%
import sys
sys.path.append("../src")

from viz import plot_efficiency_tradeoff

# example structure — replace with your actual numbers from notebooks 01-03
results = {
    "kmer+logreg":  {"accuracy": 0.0, "params": 0, "latency_ms": 0.0},
    "onehot+CNN":   {"accuracy": 0.0, "params": 0, "latency_ms": 0.0},
    "evo2+teacher": {"accuracy": 0.0, "params": 0, "latency_ms": 0.0},
    "distilled student": {"accuracy": 0.0, "params": 0, "latency_ms": 0.0},
}

# %%
plot_efficiency_tradeoff(results)

# %% [markdown]
# ## Wrap-up discussion
#
# - Where does each model sit on the accuracy/latency/size tradeoff — and why?
# - How much of the teacher's accuracy did the student recover? Was it worth losing?
# - If you had to deploy a coding/non-coding classifier on a low-power device (a sequencer,
#   a field device), which model would you actually ship?
# - (If you did the bonus track) did the sparse autoencoder find any features that line up
#   with something biologically meaningful, with zero supervision?
#
# Present your `results` chart and answers to these questions to the group.
